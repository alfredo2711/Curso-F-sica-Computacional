# %% [markdown]
# ## Decaimiento Radiactivo

# %% [markdown]
# ### Modelo Atómico

# %%
#mostrar imagen del modelo atómico
import IPython.display as display
from PIL import Image
display.display(Image.open('modelo_atómico.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=770x430 at 0x213D1A849A0>

# %% [markdown]
# El núcleo se representa de la siguiente forma $$ _{Z}^{A}\textrm{X} $$
#
# Donde:
# X=elemento químico, Z=cantidad de protónes, A=Número de masa, suma de protónes y neutrones.

# %%
#Mostrar isótopos del hidrógeno
display.display(Image.open('hidrogenos.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=850x397 at 0x213D1A03700>

# %% [markdown]
# ### La nomenclatura para cada uno es la siguiente:
# Protio $$ _{1}^{1}\textrm{H} $$
# Deuterio $$ _{1}^{2}\textrm{H} $$
# Tritio $$ _{1}^{3}\textrm{H} $$

# %% [markdown]
# En los elementos naturales la relación de neutrones a protones suele ser unitaria para números atómicos bajos mientras que para valores Z superiores a 20 la relación aumenta hasta hacerse ligeramente superior a 1,5.

# %% [markdown]
# ## Decaimiento Radiactivo
#
# El proceso de radiación fue observado por primera vez por Henri Becquerel en 1896, y la palabra radiactivo (inicialmente radioactivo) fue acuñada por Marie Curie en 1898 para describir materiales en los que los núcleos, o partes centrales de los átomos, son inestables y pueden cambiar espontáneamente

# %%
#Imagen de Henri y Curie
display.display(Image.open('descubridores.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=804x446 at 0x213D1A03880>

# %% [markdown]
# Debido a las cargas positivas de los protones estos están constantemente rechazándose los unos a los otros.  El núcleo se mantiene unido por una contrafuerza que se denomina interacción nuclear fuerte generada por los protones y neutrones. La mayoría se mantiene unida en una situación estable, pero algunas combinaciones de protones y neutrones no pueden mantener el equilibrio y espontáneamente (debido a una interacción llamada débil) cambian o decaen hasta alcanzar una forma más estable liberando partículas y/o radiación electromagnética.
# Estos cambios son conocidos como radiactividad nuclear, y esos núcleos son isótopos radiactivos o radionucleidos.  Para alcanzar su forma más estable algo de la energía del núcleo debe ser liberada y esta energía que se libera es la que se conoce como radiación.

# %% [markdown]
# ### Radiación Alfa

# %%
#Imagen de radiación alfa
display.display(Image.open('radiación alfa.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x451 at 0x213D1A09070>

# %% [markdown]
# La ecuación general de la desintegración α es la siguiente:
# $$ _{Z}^{A}\textrm{X}\rightarrow _{Z-2}^{A-2}\textrm{Y} +\alpha $$

# %% [markdown]
# ## Desintegración Beta
# Según el nucleido, si tiene exceso o defecto de neutrones, tratará de ganar protones en su núcleo o de perderlos para lograr la estabilidad. Esto da lugar a los procesos de emisión de partículas beta negativas (β-) o beta positivas (β+) respectivamente.

# %% [markdown]
# ### Desintegración Beta negativa
# Cuando la relación de neutrones a protones es mayor que la correspondiente a la estabilidad, el nucleido se puede desintegrar por medio de un proceso equivalente a la transformación de un neutrón en un protón, emitiéndose una partícula β negativa y un (anti)neutrino.
#
# La ecuación general es: $$ _{Z}^{A}\textrm{X}\rightarrow  _{Z+1}^{A}\textrm{Y} +\beta ^{-}+\nu $$
#
# Donde $ v $ es un (anti)neutrino

# %% [markdown]
# ### Desintegración Beta positiva
# En la naturaleza no existen emisores β+, sino que se producen por acción de deuterones (núcleos de deuterio) o partículas α que inciden sobre los átomos de ciertos elementos.
# La desintegración beta positiva consiste en un proceso equivalente a la transformación de un protón en un neutrón, emitiéndose un positrón y un neutrino.
#
# La ecuación general es: $$ _{Z}^{A}\textrm{X}\rightarrow _{Z-1}^{A}\textrm{Y} +\beta ^{+}+\nu $$
#
# Donde $ v $ es un neutrino

# %% [markdown]
# ## Por Captura Electrónica
# Los núcleos con relación neutrón a protón en defecto, pueden pasar a una condición estable por captura electrónica. En este caso se captura un electrón orbital (básicamente de la capa K), posteriormente, tiene lugar un proceso equivalente a la transformación de un protón en un neutrón emitiéndose sólo un neutrino.
#
# La ecuación general es la siguiente: $$ e^{-}+_{A}^{Z}\textrm{X}\rightarrow _{Z-1}^{A}\textrm{Y}+\nu  $$

# %% [markdown]
# ## Radiación Gamma
# Como consecuencia de un proceso de desintegración α o β o de captura electrónica el nucleido hijo puede quedar en un nivel fundamental o bien un estado excitado, entendiéndose por tal, aquel en el que posee un exceso de energía con respecto al nivel fundamental. En estos casos el núcleo se desexcita emitiendo radiación electromagnética. Esta radiación conocida como gamma es similar a la luz visible o a los rayos X pero su origen es nuclear y por tanto su frecuencia es más elevada.
#
#  La ecuación General: $$ _{Z}^{A}\textrm{X}^{*}\rightarrow _{Z}^{A}\textrm{X} +\gamma $$
#
#  Donde $ \gamma $ es un fotón

# %% [markdown]
# ## Decaimiento radiactivo
#
# Una manera de ver las leyes que rigen el decaimiento radiactivo es utilizando la curva experimental del $ _{}^{14}\textrm{C} $

# %%
#Imagen de decaimiento del C-14
display.display(Image.open('decaimiento.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=689x413 at 0x213D1A03DF0>

# %% [markdown]
# La expresión que describe la ley exponencial del decaimiento es la siguiente $$ N= N_{0} e^{-\lambda t} $$
#
#
# En esta ecuación, N representa el número de núcleos del padre en el instante t; $ N_{0} $ es el número de núcleos iniciales cuando t = 0; λ se denomina la constante de decaimiento; e es la base de los logaritmos naturales. La constante de decaimiento λ representa la probabilidad de que haya decaimiento

# %% [markdown]
# Implementamos el concepto de periodo de semidecintegración $ t_{\frac{1}{2}} $, donde por cada periodo $N(t_{\frac{1}{2}}) \rightarrow \frac{N_{0}}{2}$ por sustitución nos queda que $$ t_{\frac{1}{2}}=\frac{ln2}{\lambda} $$

# %% [markdown]
# Otro parámetro que puede obtenerse a partir de la primera expresión es la vida media ($ \tau $) del nucleido que representa el tiempo promedio que “viven” los átomos de una fuente radiactiva. $$ \tau=\frac{1}{\lambda}= \frac{t_{\frac{1}{2}} }{ln2} $$

# %% [markdown]
# Entonces tenemos que:
# En una sustancia radiactiva dada, el número de átomos que se transforman, (-dN), en un lapso de tiempo (dt) es proporcional al número de átomos presentes en ese momento (N) y con la constante de proporcionalidad λ que es característica de cada nucleido se puede plantear la ecuación siguiente: $$ \frac{dN}{dt}=\lambda N $$
#
# El primer término representa la rapidez con que se desintegran los átomos del material que antes fue definida como actividad (A) de un radioisótopo, luego: $$ A= \lambda N $$
#
# se puede calcular la disminución de la actividad en función del tiempo: $$ A(t)= A_{0}e^{-\lambda \tau } $$

# %%
#Simulamos el decaimiento radiactivo con matplotlib
import matplotlib.pyplot as plt

# %%
#definimos variables
p = 1/5730
dt= 1

# %%
# Establecemos un bucle
n = 10000
t = 0.0

tlist =[]
nlist =[]

while t < 20000:
    n += -n*p*dt
    t += dt
    nlist.append(n)
    tlist.append(t)

# %%
# graficamos
plt.plot(tlist,nlist,"-r")
plt.xlabel("Time(a)")
plt.ylabel("N")
plt.grid()
fig= plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#simulamos con número aleatorio y numpy
import random
import numpy as np
#definimos la función de decaimiento
def decay_sim(thalf, N0=10000, tgrid=None, nhalflives=4):    
    tau = thalf / np.log(2)
    if tgrid is None:
        Nt, tmax = 100, thalf * nhalflives
        tgrid, dt = np.linspace(0, tmax, Nt, retstep=True)
    
    else:
        Nt = len(tgrid)
        dt = tgrid[1] - tgrid[0]
        
    N = np.empty(Nt, dtype=int)
    N[0] = N0
    #La probabilidad que tiene el nucleo en decaer
    p = dt / tau
    #aplicamos un for para incluir los números aleatoreos
    for i in range(1, Nt):
        N[i] = N[i-1]
        for j in range(N[i-1]):
            r = random.random()
            if r < p:
                N[i] -= 1
    return tgrid, N

#Simulamos el decaimiento
N0 = 10000
thalf = 5730
Nt, tmax = 100, 20000
nsims = 1
tgrid = np.linspace(0, tmax, Nt)
Nsim = np.empty((Nt, nsims))
for i in range(nsims):
    _, Nsim[:, i] = decay_sim(thalf, N0, tgrid)

# %%
#Graficamos la simulación
plt.plot(tgrid, Nsim,"-r")
plt.xlabel("Time (a)")
plt.ylabel("N")
plt.plot(5730,5000, marker="o", color="black")
plt.grid()
fig = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Comparamos gráficos
plt.plot(tgrid, Nsim,"-r")
plt.plot(tlist,nlist,"-b")
plt.xlabel("Time (a)")
plt.ylabel("N")
plt.grid()
fig = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Animación
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

x = tgrid
y = Nsim
fig = plt.figure()
plt.xlim(0, 20000)
plt.ylim(0, 10000)
graph, = plt.plot([], [], 'o')

def animate(i):
    graph.set_data(x[:i+1], y[:i+1])
    return graph

ani = FuncAnimation(fig, animate, frames=100, interval=200)
plt.xlabel("Time (a)")
plt.ylabel("N")
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(block=None)>
